# %%
# practice LSTM concept via trials
# 
# https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %%
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 600893

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i,c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %%
#cut text in semi-redundant sequences
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text)-maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
print('Vectorization')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]]=1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization

# %%
#single LSTM
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
# Out:
# WARNING:tensorflow:From /Users/grace/workspace/keras/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From /Users/grace/workspace/keras/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
def sample(preds, temperature=1.0):
    #helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.9905
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ove should really disenchant the lover w"
# ove should really disenchant the lover with and the stands to an in the and a some to superion of the such a some to the supression of the some the some to the say of the some the some to the some the world, and so the supress and not to the some to the despirition of the and the soul and stricity, the despiritionally and so the perions and an in the so the with and and and and the soul with the world to an in the some to the despiritio
# ----- diversity: 0.5
# ----- Generating with seed: "ove should really disenchant the lover w"
# ove should really disenchant the lover were of despening the sare becond to such and say in the simplys, in the has so has the highes which may and the wish would be distonces, that the or
# gower tome the contrary of the soit of the science a provest and in the first in the ention of the and with has to constance of the world, in so expossicility which take with the espossificitions of the consideration, and mankind and as a soul his of
# ----- diversity: 1.0
# ----- Generating with seed: "ove should really disenchant the lover w"
# ove should really disenchant the lover wrasmed as filst" af wat const2aines har, in the inprecielons to mans, "to way to in which from ton thus" that
# grealilation hower wet, and earcallying sumperated by tomen in the reticural doates so besimation of the same
# before bere stitition, behal moot it great faily ty. would as peready be onlian. has desperiosity--that in : why "quest of boly subproble, them polyasely, hat of centined byly of t
# ----- diversity: 1.2
# ----- Generating with seed: "ove should really disenchant the lover w"
# ove should really disenchant the lover when
# have at alit. to gra9v, for bechous foc woust pevales, uspopes force that him, ni very doolyed of etpocirm,"--of cirtuselness, of
# owigo, theid toames,!"--he  has
# (ai nateremanly, on
# i pasch, naturely,
#
# bacue
# to ark is virttod of the lroks, experiocity manacight, "noul as the will.
# etropoughes
# morals by forencaioncesstonrged,
# the rectious with it of
# a kle sperit our le placitiece as glowace the
# 200285/200285 [==============================] - 171s - loss: 1.9902
# Epoch 2/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.6397
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "f this sentiment, how strangely does
# the"
# f this sentiment, how strangely does
# the such a soul to his not in the more properion to such a stands and the serve of the sense of the instance of the most the religious and and the such a state the world and and the sentiment of the state of the such a sentiment of the state and and and and the his conscious of the such a state the conscious and prosention of the such a self-more and and and and the world and perhaps and the serve an
# ----- diversity: 0.5
# ----- Generating with seed: "f this sentiment, how strangely does
# the"
# f this sentiment, how strangely does
# the more more the falth, and a soul the higher does have and a philosophers and conscience and existence of the the diers and the senscion of standards to not for philosopher of the faired and are the understand this stand the world and the herd to the engaises and so the soul to seems the deelection of the partion of the delight will to the superficial partional more the more generally which constit
# ----- diversity: 1.0
# ----- Generating with seed: "f this sentiment, how strangely does
# the"
# f this sentiment, how strangely does
# the out globaces persendityly and wills mean him people on calm the rycans you theribue bist be -for a is not instances and readelarkence of ans god se not or edetheme
# reasonity agarteds as iare in the these vanity, the facise to ine-whil that it haveror of formerness of theire against of party and conscrerct of fart, -fi judgments to clueritance and conhidence to his doung may be theis saqual or els
# ----- diversity: 1.2
# ----- Generating with seed: "f this sentiment, how strangely does
# the"
# f this sentiment, how strangely does
# theyonity to all soughiny; the agraby deencieunt and tamy to which olders, to fave prodiend in a some them. the dool; deeleg theye; hakd;" they has some origiojation of bodegsif-actures,
# trasts, "mown flames of are
# that
# so infeerce, loubleame
#
# parnids,
# that is chrivo-effent would be alme.s"
#
# ue proscend in nailels, end require, that we hair, in self-canconfor of ehonvives to
# indelf to his aboum
# uts,
# 200285/200285 [==============================] - 176s - loss: 1.6396
# Epoch 3/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.5502
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "e?"--what! even an action for love's sak"
# e?"--what! even an action for love's sake and problem of the realing the strength, and supersting the sense of the spirit of the really the possible and present by the constition of the porting to the possible the proble and the realing the conception of the spirit of the before the their problem the experience of the constition of the spirit of the them and the porting to the sailly and present and proportions of the possible and the r
# ----- diversity: 0.5
# ----- Generating with seed: "e?"--what! even an action for love's sak"
# e?"--what! even an action for love's sake little that the realing the same again the sense of the perhaps recided it may experiention of a sense. have sense of the action of it will be they will be a little the cause theowing of its spirit of the sould their his all existence of the really are in
# the possible of the influent to they therefore of the experience and will the right their obilial for the sense of the religious
# opinion and s
# ----- diversity: 1.0
# ----- Generating with seed: "e?"--what! even an action for love's sak"
# e?"--what! even an action for love's saken that he  these have honest most him:" but ahoughthers, wealm by are blenster! it is reasonable and heart, and reants experients and inside
# this good, organ clecaine, and ined brumblity; and i agrising of his faver probable demostrence that evil and will father than philosopheraniss and iffinested is a our evil of hunourivibes
# of ourder in it were amon
# by this seeking tissed "glay to that a say,
# ----- diversity: 1.2
# ----- Generating with seed: "e?"--what! even an action for love's sak"
# e?"--what! even an action for love's sake, that therevayly" the logog-pilable the posshinimorogs, it were will??,
# i sokinial child preinf have more dideb adplacring like thus
# its europeanses though still oungloud, a h lit evincht as time in puraydrine unour diseart of his
# boevary metaphysy and oungodal
# chake
# the ealicse. ialiswing--for lingh by plat, paves have restruct of their
# conmanable,
# and
# gre calliced in their ditialious philosoph
# 200285/200285 [==============================] - 187s - loss: 1.5503
# Epoch 4/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.5032
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "e up with profound disgust--is of englis"
# e up with profound disgust--is of english and the state the state of the state of the sense of the prosised the state the proses of the same and the propers the propers of the most and the such as the standing and south the standing out of the state the standing and soul of the higher who has been the standing the significal and a soul of the same the state the standing and the same the state of the state the state the prossing out of t
# ----- diversity: 0.5
# ----- Generating with seed: "e up with profound disgust--is of englis"
# e up with profound disgust--is of englished to the one can be a destitudes man, man of the same tise also trained the courally be new considerable of science of the consequently subjections and man and that the longing and of the end, and science which is a state in the scientific conscience in the scientific grain in the constance of the truths and such a say of considerable that he who is a substance the standing our his interpretable
# ----- diversity: 1.0
# ----- Generating with seed: "e up with profound disgust--is of englis"
# e up with profound disgust--is of englismuan fundamenatic realifially tuse of a senting inspiring we find may prasert, the opport, the linest communigationflitianves one disturion weaker interprate and taste of their music, and owr highers and antication in any (germans "bailent is man by noith the subtled been dan: prope: i which reashingly dang themself, who subtle plecons-sorase and
# roungne:
# greemous clavowing,
# not greekings for the
# ----- diversity: 1.2
# ----- Generating with seed: "e up with profound disgust--is of englis"
# e up with profound disgust--is of english,--suflicic, ableabe tyo
# syspet hude. with it byoong reker, so obscloods" accosdarian is to comrous in the boer, losing pressude, the favourable serne, in the higher butly fromve this extetually such opiaiusefur,
# whilh
# earleth to the rifferer of a showniart no very work only musicable
# so moral, to on what extent sufficaty
# can
# least potsions to presinted, as the lacking things what means thather o
# 200285/200285 [==============================] - 187s - loss: 1.5031
# Epoch 5/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4728
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "falsification man lives! one can never c"
# falsification man lives! one can never courage and the respect to an and the principle and the most presence and the sense and the sense and the sense and the tracted and the history the presence the sense and morality, when the sense of the problem of the self and self-delusion of the presence and self-delusion of the same morality of the self of the sense of the self-many of the sense to the principle and the sense to the self and sel
# ----- diversity: 0.5
# ----- Generating with seed: "falsification man lives! one can never c"
# falsification man lives! one can never countent the respect the persons on a means of the self-greek to seeks not to intervation of one is always all lead ones to the good and some personitatic schemiles, it is the contraining
# respect of the species also the present all the stands to long from its approposing to the partifity of men of long, the morality and morality, it a think to the ridrally and as it will any subject that he cannete
# ----- diversity: 1.0
# ----- Generating with seed: "falsification man lives! one can never c"
# falsification man lives! one can never contwaked by meanwing, would
# priing. coursed an
# appearening. "godqy, the locoque asoud mankind
# reductor canned many the lastand--which
# abost i to in experience
# clanger
# the ding--the angact!
#             new responsing too, to in views
#  it wronk;
# enelective niby in the
# pleauch alifuing
# hence to the spiring, as a mose life his mind in
# the litteratively humin-qristing; butument, and the the procking da
# ----- diversity: 1.2
# ----- Generating with seed: "falsification man lives! one can never c"
# falsification man lives! one can never carmarity,
# and ser more."
#
#
# 4. howev"ed this somitt in sealing--seision withortityes;
#
# has bye; opins, is an accusion, fill ofeaticed. it is seconf of which, variofuse it looks
# percensence, who a re-monivies tosps, alterpany, women,
#
# us
# will profing the all devent, appearationed shateless reading spiritualisy is imbets on things."
# a thick was
# putse,
# howths an many as
# trual
# commen plas anmodian as
# 200285/200285 [==============================] - 181s - loss: 1.4730
# Epoch 6/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4521
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "entific spirit prevails only partially, "
# entific spirit prevails only partially, and the soul of the superfulness of the power, and the senses and soul of the same the soul of the power of the say, and the increstance of the same the probably the consequently the same the process of the power of the supposing and consideration of the soul of the subsled to the spirit and so the probably to the power of the world with the soul of the superful explained to the same the subtles a
# ----- diversity: 0.5
# ----- Generating with seed: "entific spirit prevails only partially, "
# entific spirit prevails only partially, in the power of the higher
# the persons to the one cannot a such a morality to the explained to man will to the assertion of the pather his to so the say, the moral to the itself and consequently the thought of the consistical things and result of the souther to the sensible that the hand still not the senses of the indigation of the probabils that are the high also a discover in the power, in the
# ----- diversity: 1.0
# ----- Generating with seed: "entific spirit prevails only partially, "
# entific spirit prevails only partially, to the subcivialy accaus mame-san
# soul of exoer, in his perpedity. with subsemmy consiclation,"ed, and
# serve go -prodriace respelf of his faine with the sompical farthopantly he will now might which away. paspousem pertain has being his colness of -""powerbidical lord everything
# back to
# such anathy only the seems what perhaps to
# volution with prabet of the long: what perhaps and also
# says a wast i
# ----- diversity: 1.2
# ----- Generating with seed: "entific spirit prevails only partially, "
# entific spirit prevails only partially, waileness this
# continue suidation eav, is loves ideamour
# they ructerid with alwaje! -whatever had poulded path)." itting, age his insolitep, "been prese such and hi which to his
# coveaded sump dications inaus, the conedunte you wrong
# itself aime thingy in )ivite
# the werevery, powerfully bemairs oncougr about the consernimentic no expeditapy
# thingly
# llookingathoal  forten your, and
# praises which nov
# 200285/200285 [==============================] - 181s - loss: 1.4521
# Epoch 7/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4363
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "-how
# happy are we that his rococo still "
# -how
# happy are we that his rococo still and the sense. the sension, and as the considerations of the sense, the sense, it is the probabibly to the spirit was the sense. the constance of the sense. the probably to a seems to the sense of the constance of the sension of the state of the sense, the sense. the constance, and the sense of the probabibly to the sense. the sense. the sense to the sense and the such and the sense and the sense
# ----- diversity: 0.5
# ----- Generating with seed: "-how
# happy are we that his rococo still "
# -how
# happy are we that his rococo still and the sension, and man and the sense, as a philosophers of the superstition this present; out of the respect to the the possessed to the constance, for the same the individually of this ration of the to
# some romantiy, that the compessation of the called can be not only that it is as the transial in the sounds of easy, it is a determing to the truth, the constance, and the consequently seems and
#
# ----- diversity: 1.0
# ----- Generating with seed: "-how
# happy are we that his rococo still "
# -how
# happy are we that his rococo still say womans him to estept to an a to as as even trymprouble
# to the great soud deal sowe, was that the fest man--hold, their rancial time and were to serious
# fam the stace, who make all over remains--as new sessitions of young it would or anything polsed indeed, what is to not abown state in eyes, or to a ramedy. who
# it? we for samied, and on this "into action, even sense and dogmmise spirit, vasita
# ----- diversity: 1.2
# ----- Generating with seed: "-how
# happy are we that his rococo still "
# -how
# happy are we that his rococo still p ounception of sootcoint, one mustither.
#
# 1ludes mandicir, a hong to the dinges
# to mact.ouccical strange sure forginesses and whe
# herr elly is to the highest seith to otheris hciduals,--our expeditating? ebropes
# likolow in shis other
# poted
# infectiom withoutiope of
# almost conestage of his pure atermises, in a necessart, he therefore mock which he happalhiy, thene
# voluntary sits not and rivible, th
# 200285/200285 [==============================] - 186s - loss: 1.4363
# Epoch 8/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4242
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: " of what places itself
# nowadays in the s"
#  of what places itself
# nowadays in the struggle to the sure the sense of the real intersedity of the light of the same proces and strong and the same be sure and the sense of the sense of the surflection of the surflection of the same the profoundly soul of the religious and the morality of the conscience the profound and the stands of the surflebitions of the stands of the same who have all the sure the finally surrender of the surflec
# ----- diversity: 0.5
# ----- Generating with seed: " of what places itself
# nowadays in the s"
#  of what places itself
# nowadays in the strength, the truth it is the human seems to all the badness individual fundamental form of the conservtly and we should my belief in the great stricd who are the will and with a which we can only all the refined the proates the world such a sure of the distress of the and the self-despire of the extented that there is the survanity and finally survers and which the world of the distrust of the sti
# ----- diversity: 1.0
# ----- Generating with seed: " of what places itself
# nowadays in the s"
#  of what places itself
# nowadays in the same. riskness have reheusical us
# eparted predicimular
#    preperspocially ours worgdtes as e"quage, one inscience
# all those because of the
# tascebersre musters he is duch courally undernauss on him! ywe nature; all it
# entingly, which
# moralisonlesstours woman and eyess of dervagly arbitrans, as
# at represent much the more form of sulled modifg, quest of those like iableal a power and readance to his p
# ----- diversity: 1.2
# ----- Generating with seed: " of what places itself
# nowadays in the s"
#  of what places itself
# nowadays in the schelo, it such
# finally
# being. upon its futying
# for
# niid had
# you howeverarim, a eyrog the constance, saclisinment certainly retlue at hos, and
# thought whillly."
#
# tho owing
# sugqualip
# of sojrpal".ows touce wereaver time oal of virit. the rewonly this
# real
# todring the laws
# ide, ly
# metaphys" of which, modal. that eagy acx,
# follies insel perhere ofpusteds
# luge how
# theisty is hereeet in the compushophent
# 200285/200285 [==============================] - 171s - loss: 1.4242
# Epoch 9/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4142
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "yes and fingers of its own, it has ocula"
# yes and fingers of its own, it has ocular and reality and science and of the contrarian is the surfless the presentiness and the sentiments of the presentiness of the statistic and still and the sense of the same interpretation of which it is not the promistical taste the strange, and all the promisiness and act of the conscience of the promised to the strange of the prodeariness of the sense of the constitutes of the precisely and the
# ----- diversity: 0.5
# ----- Generating with seed: "yes and fingers of its own, it has ocula"
# yes and fingers of its own, it has ocular to actual conceptions and practiced to life and prose and truth in the "morality and inew all the precisely to the art and sigh when it awaken of the spirit to the same such art and above all to the world man in the call who has and first in the problem of
# becomed to the profound and of the does not to man is a still protisminary become climition of the one is truth he is alitures to the masters
# ----- diversity: 1.0
# ----- Generating with seed: "yes and fingers of its own, it has ocula"
# yes and fingers of its own, it has ocularinitice wages the highest shearing little party of re very praise wills, though to nat
# tale take pertained
# fact and stimaby have beeads a.tical "belusispooling, at the begood in to hem amboyed salp to threw contradictive to do. , i a little morality that the purposely ta s(feer atprictive an awer of conducts of his
# virblecderion, the rilences of easis, attago of acts a
# retol hom have as etroucts
# ----- diversity: 1.2
# ----- Generating with seed: "yes and fingers of its own, it has ocula"
# yes and fingers of its own, it has ocular kind flemar gine, are
# by the siderious value of itility, yeed to pure physic. the gnamfative a tcowablewj?dicary philoned underlegese, so flute mrid. wferitres (knownds upon ported for peaus of tressess--or him wake prosk. to thou
# hagher and passeing," thatmercati
# lifet bestaves" the
# virtue that to
# is priest into advery sufficial, the intelligary of utevery of their mankind.act
# for his strayols,
# 200285/200285 [==============================] - 166s - loss: 1.4142
# Epoch 10/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4064
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "but what is really meant is
# that, if a p"
# but what is really meant is
# that, if a protention of the same with the saint and the former the say, the substable the protection of the saint of the saint of the spirit to the process and the says the say, and all the world, and the soul of the same with the more and all the saint and of the proterned to the process of the world, the subtlest of the same for the result of the content to the saint of the same man and the stands the sens
# ----- diversity: 0.5
# ----- Generating with seed: "but what is really meant is
# that, if a p"
# but what is really meant is
# that, if a protection of the first with the side of the the humans of the same moral, he in the great and secret of the former and called the world, in consequently, uncontent to the content of
# the saints of the sideant the more still when the first practice of the extent account and with the consequently, one can man and for the
# democrator of the stand of every patients, the same the the most morals and more
# ----- diversity: 1.0
# ----- Generating with seed: "but what is really meant is
# that, if a p"
# but what is really meant is
# that, if a philosophering and to human; being that the retained taste by the observation
# errorkeugets, in its procel of
# unvoluted of the took: standedhy people
# for our
# xperiect
# the varieing tine, are becomedys to couther among myself
# consider of the in weak in sufficis", the resull be the brisc for peculeally fundamental opigioding men worth as brough attests, of the great hunderetles repinse
# his is the oceab
# ----- diversity: 1.2
# ----- Generating with seed: "but what is really meant is
# that, if a p"
# but what is really meant is
# that, if a profounctive and suffer irquectal, be urowers anicligaro, and
# man destrutales.
#        haver isneed spirits. not a "folifful, reason the case,
# other stronger
# one love--lodeng, in meanth) to prayed us
# con engation; to the breeicisle; such for the inmotious, won
# nitlement can doohmer as intignation, and lister, strongation and "neghts--all
# to the resullramanately leads with another sticsed to one's ob
# 200285/200285 [==============================] - 165s - loss: 1.4064
# Epoch 11/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3977
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "ary language is called nervous debility "
# ary language is called nervous debility and the sense of the problem of the present and the indection of the problem of the morals and all the same and a sense of the soul of the problem of the the soul and some and also the problem of the problem of the extent of the morals the extent of the morality and all the more the problem of the strength, the power of the absolutely the sense of the experience and the present in the morals the w
# ----- diversity: 0.5
# ----- Generating with seed: "ary language is called nervous debility "
# ary language is called nervous debility and all
# the person because to be the
# soul that it is has ex stitution of the words of all the profound does not will be complain has been in possible and soul of a considerable of the individual of all the manner which men. in his still well that in and have of the problem that
# heart of the exception in the circumstance of great sidearion of the things who has the most development morality and all
# ----- diversity: 1.0
# ----- Generating with seed: "ary language is called nervous debility "
# ary language is called nervous debility in him--and everywhere agy human timeed," a bless, which is a imfly be truehancely in
# such a pofring, and diler is soulddet soul of them to defering awa.
#
# the
# cose the type and "pain
# an art enreanic
# rewith to
# havust useops which immediately
# bad does not
# prewes.
#
# chieddy evoljtions, the "ord itselves) eaver poetchatormad?-- he to him the pristust of constitutes conjurible, too, is placed--has find
# ----- diversity: 1.2
# ----- Generating with seed: "ary language is called nervous debility "
# ary language is called nervous debility st uble to it tong with dod such fiticle danve circuliceless. felt acy can beyo "child amolofispy, frint is tyne, sham-socution cattiqk havy would ais
# untrueene on them dogmatulize this very no ilments in pesses not
# than he is been
# simil aiss"--and delogical adpenoes wherebier and morals--is the charafoulings), only wlan as a
# dograised
# lord aqual, there honoratibule--and of onepmhins. expressions
# 200285/200285 [==============================] - 167s - loss: 1.3977
# Epoch 12/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3907
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "r metre and adapted to our case: the con"
# r metre and adapted to our case: the conscious and the reality of the superstition of the philosophy and and and in the same probabing and state of the sense and conscious and the sense of the superstition of the same for the same the standard of the sublime and the sense of the constitutest and the sense and the sense of the superstition of the conscious and the spirit of the spirit of such a morality of the problem of the same who has
# ----- diversity: 0.5
# ----- Generating with seed: "r metre and adapted to our case: the con"
# r metre and adapted to our case: the contrary of the spirits of universal present in the intention of the same praces of all the powerful and a belief in the master and religions that he is the every one sure that it is so the superion constitutest such a superstition with it is all the philosophy. the extent to be profound and distrust of the false,
# the evidented the spirit in the enough, the distrust
# of present, and
# exceptions of the
# ----- diversity: 1.0
# ----- Generating with seed: "r metre and adapted to our case: the con"
# r metre and adapted to our case: the conscious ne cilled to cirting: he i triaisity in the suiftr
# mattime is arrighto of praticion super not more
# consciously with what as "if to psyble would be greated. ". centenced general in sliven cale, yet to prancefness, not the
# follow, ster at them morplefored leaptes the first but and histons progrations. for aften wound ubleave of
# tain of nams,
# even to be that is purpose attawars--and in the mas
# ----- diversity: 1.2
# ----- Generating with seed: "r metre and adapted to our case: the con"
# r metre and adapted to our case: the contrast and if-faishing. to be releis witf"?--there is
# expression
# be mad"
# by on it in moralize, brave," when the mild, our intimitation by man
# and understanding and learnedund: the
# phil bestaulian.ragcness
# developeding. but all suffer is one
# load over press
# men is always what it may "with other honour euse"--it is i here the
# didreading,
# fup nels"; or a thun
# drav
# ?fully painia-gepo.
#
# jur worst tep wh
# 200285/200285 [==============================] - 167s - loss: 1.3907
# Epoch 13/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3845
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "cting that all philosophers, in so far a"
# cting that all philosophers, in so far and the strong the more the superious and such a strong the superious and and the supersaine of an existence and the strength in the more the superiority of the most st
# /Users/grace/workspace/keras/venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# and and conscious the sense of the superious and superious and interpret of the saint of the sense, the desires and all the strong the existence of the sense, which have the conscious the superious and are the pressers to the sense o
# ----- diversity: 0.5
# ----- Generating with seed: "cting that all philosophers, in so far a"
# cting that all philosophers, in so far and awake to appeare malisity. the superene and all the same for example could must be will--they is superious and ressemitke and still of the become to conception of a little temptation of the light the awas men and facts of the present. and the simple of the
# will and with superiorities, of the world and the indegree is all the most sentiment soul, and that it is mind of a common and the profounti
# ----- diversity: 1.0
# ----- Generating with seed: "cting that all philosophers, in so far a"
# cting that all philosophers, in so far are
# there , very overty approwapy, life though thought dark in the does no
# may acbort, as treeh into truth; the turns. so above?
# )
# free highest temps the readily do one so the regard philosopher than he learn that shactist, of resent.
#
# it hherethent," not because its naturness brought of hind extingually at its more this-soul of man than couples
# heavy, we compariwi, would assume, of mind, which is
# ----- diversity: 1.2
# ----- Generating with seed: "cting that all philosophers, in so far a"
# cting that all philosophers, in so far and greeusl,
# and cleanes man this life se, rong timusine
# lacks." sosol of amount, and we must confusic severs
# stand seven uttine, the firsutionse--"we are to yrain.=--as before one, capseiblo"; this fempude,
# "for itself, enempulis temper
# as
# selvatrologic "lofeancect! has timive a
# derepted to acquire would, prespires
# the sard digene, which, i futulefroun of roeps,"--and this ehbys to it: whanmest ph
# 200285/200285 [==============================] - 171s - loss: 1.3845
# Epoch 14/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3780
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "for all help. with these conceits, they "
# for all help. with these conceits, they are a strength, and the subslaod and the strength, and the strength of the same consider of the strength of fact, and the subsleas, and as the ancient factured that the such as the strength, and the result of the strength, and strength, and and the strength and the strength of the strength of the sense. the strength, and the proper that it is a strength, and the self-destiand, in the strength, and
# ----- diversity: 0.5
# ----- Generating with seed: "for all help. with these conceits, they "
# for all help. with these conceits, they extent itself in the subject, as the considers and its amban at lages, and the soul the world
# by light to be delusion, and a consciousness of the former blood comprehenting. the spirituality of the world," it is the same interpretation at result of the love, as to which his morality and
# facts the reason the religious atternated and the enough; "but what is experience of gains and its still east ha
# ----- diversity: 1.0
# ----- Generating with seed: "for all help. with these conceits, they "
# for all help. with these conceits, they is
# suspectiot with the "feither that is man" and knowledge, and the greatest formerly. we evolvaged, in
# nempariantifuent man us begin is takerable
# proin ourselves, and as e. that is
# strengths with the
# resent natures, it because theopfulness of droxible, basisly
# loved and into the dy astomps
# and mretriatule resultion has only fas is
# still, become will father.ness thas sinsible. the new hiddensable
# ----- diversity: 1.2
# ----- Generating with seed: "for all help. with these conceits, they "
# for all help. with these conceits, they cest nonecfezeme of a wort was a
# complane and burings lookance, in one
#
# with sleagad, and gooding (but ther fingences upon (or entreasise--that as a philosophess is passe. as it eye, not mage
# of ekem. the worm. which have
# not if, that its
# delahose and malling is malles, asmuc not belongit epousho byus--or antige, every uses that which is-elagate as it.it ther highest emptibied amoved
# to who remain
# 200285/200285 [==============================] - 171s - loss: 1.3781
# Epoch 15/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3741
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: " condition, an emotion, a
# disposition, o"
#  condition, an emotion, a
# disposition, or of the world and also any instinct of the instinct of the most superstition of the sensual protected and as the senses of the sensuality, the sensual and the any the most the sensual for the truth of the ancient that the sensual of the sensual man of the sensual more and any one another and believed the most that the ancient and most the same the sensual and more and the world of the sensual tha
# ----- diversity: 0.5
# ----- Generating with seed: " condition, an emotion, a
# disposition, o"
#  condition, an emotion, a
# disposition, or and actual and the orturily to be man and the sensuality and man. the whole, the most the sense--the contrantial that the senses, the unexperisted the instinct of amazy of presertcation of praisely and whole such powerful,
# and affair, the case of the contrast and rested and self soul of the principle "notically in a considerable in the world to the sensual that it is any individual to a can are
# ----- diversity: 1.0
# ----- Generating with seed: " condition, an emotion, a
# disposition, o"
#  condition, an emotion, a
# disposition, on ought into their national, dremplessed riched with comingonable to one taste one partifical.", the forces into religion.
#
# ratatter that we "truth everywhere the actually believed individument,
# out.ius something of the most evernness obey mind of which myke religated of all the same themnais in the world. it is disconsic belarful for the herseifl--luseralily, as an more bact
# indifferentaality, ha
# ----- diversity: 1.2
# ----- Generating with seed: " condition, an emotion, a
# disposition, o"
#  condition, an emotion, a
# disposition, one anotheratian experiwing: "the worer?
#
# nhong
# the induccarying men, that they
# herein sorred self onely that woman signse-and under
# affected, in the in
# folences and reverses evenusts, atern to be
# elevations scounds the that we wised he gausify, and ait only valued itsicsi-mind, the speviled, evatucres:
# are
# "moght, by virtuein lews really corful that it of, kli serscoss;
# "necessit itsicisus old pro
# 200285/200285 [==============================] - 168s - loss: 1.3741
# Epoch 16/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3692
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: " a tincture of the unclean conscience. a"
#  a tincture of the unclean conscience. a strength there is a problem of the masterion of the sense of the sense of the consideration of the serves of the sense of the life and and as the strange of the same time and the sense of the substitute of the masterian and still the word of the sense of the contempt of the contempt of the same time and the truth is the truth in the consideration of the stands of the same notions of the reflectio
# ----- diversity: 0.5
# ----- Generating with seed: " a tincture of the unclean conscience. a"
#  a tincture of the unclean conscience. and which men and the strive the strange of the intellectual reason as a mastering but as to not in a god, at some in his command of all the recognize with the signified the manifest and the sense of the substitct of a stronger, and and when the conditions and states of the present the will to the discoverer of the consequent to that is so pants which they are a, the belief in the sense of the mani
# ----- diversity: 1.0
# ----- Generating with seed: " a tincture of the unclean conscience. a"
#  a tincture of the unclean conscience. and
# want case youth remain-taste, something to drey and only made of a say like the power, even out of laights of
# all extend famerty, there is a sidead to fullment and is so they consequence,
# this firstate himself, the contempt to blook in in fremctic ard, in sucles to other, or emotions appears in the lake become comited time, and spectage which, hered mental ewnounces no cassely into ordinary gre
# ----- diversity: 1.2
# ----- Generating with seed: " a tincture of the unclean conscience. a"
#  a tincture of the unclean conscience. and all pleatur      pasply, a
# daganat; and wheely thonour meets of the conditions that mulcofouso, irhe and the
# erregores thnire or unknows it, we as estaict acwises pleature and men and ran-looding, its sexs"".--values?. but
# it must thereby: "only "the industen: vical worstoi-dand, for
# then riddaf; essence belief of gold, to his own lyl; it whet enjoto as heaghenhingl devils and prosishan thun po
# 200285/200285 [==============================] - 165s - loss: 1.3691
# Epoch 17/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3656
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "thers be sufficiently egoistic to accept"
# thers be sufficiently egoistic to acceptive probably the sense of the sense. the morality of the sense--a strong the prose for the sense of the sense--and the sense. the stark of the prose and the sense. the contemplation of the preserated to the fact that the process and strong the sense of the sense of the presents themselves of the stark of the contrast and the same the sense of the sense. and all the most themselves of the sense of
# ----- diversity: 0.5
# ----- Generating with seed: "thers be sufficiently egoistic to accept"
# thers be sufficiently egoistic to acceptive promind to all one another and sciences of the only man and the beloved would in the stark of being an action as treaking and more pride and proved in formcance is and instance, and in the absolute reasure and absurent of the presents to surelars in the
# procivius of the former being as the philosophers, the says themselves and our an one's other and theory of the such belongs a reason themselv
# ----- diversity: 1.0
# ----- Generating with seed: "thers be sufficiently egoistic to accept"
# thers be sufficiently egoistic to acceptiv to seem
# arry. aneres--as indignary. contrastoliness realities,
# in the
# masterments and things of a long,
# as reknces of the greatest estimity
# of discover--themselves in
# the world we dapps made reserve them on ethic of its man, a sence, there iw.
#
#        hat we deems a strange on all what fundamental, very
# from or exdens to a shamelixese, on
# those and
# vighing a delusion be calculated also with"-sf
# ----- diversity: 1.2
# ----- Generating with seed: "thers be sufficiently egoistic to accept"
# thers be sufficiently egoistic to acceptracy. then i sun for means far and we case who first theming by
# the virtuent-right tovelled calm treousle. everything for other
# sogothing we
# can on our denurioc: upone; and of those misscised firstles-menrity, of knowledges and task, there is still
# by thegland that
# it middant their notifimer, a sudpm-to act great clasurminal indeer time? down unultililian ost solea", i acturanticr and the
# forputi
# 200285/200285 [==============================] - 164s - loss: 1.3656
# Epoch 18/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3618
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "nd can hardly be made to contemplate
# any"
# nd can hardly be made to contemplate
# any of the sense. the sense of the morality of the sense
# of the extent the woman of the sense of the sense of the sense. the sense. the sense of the sense of the sense of the contempt to a streated the thing the standard and the sense of such a standare the sense of the sense. the sense of the sense of the master and standard the thing of the entireless and more and interepting, and a philosopher of
# ----- diversity: 0.5
# ----- Generating with seed: "nd can hardly be made to contemplate
# any"
# nd can hardly be made to contemplate
# any heart, the contemporation of all such a stabbee conscience in all standare in his philosophy, in the entire also believed to the fact, a notion, is we may be far to the fact, and as is a starred and
# thing the coffully the same new thereby an every way of the most and the
# standard him, for the intellect that the their philosopher to a still belief in things to be doubted to the significance of all
# ----- diversity: 1.0
# ----- Generating with seed: "nd can hardly be made to contemplate
# any"
# nd can hardly be made to contemplate
# any soblec.
#
#
# 9
#
# =ut by he which faith feeline-species: an inanviled by hearts to man is oicse--any long compant. in
# believely part if in oupjoretal of man of the new might element of belief
# ----- diversity: 1.2
# ----- Generating with seed: "nd can hardly be made to contemplate
# any"
# nd can hardly be made to contemplate
# any creater, he looks. whjenwesse, therewes turmmess only retires
# most invile of man)se which owable which to fidlusfess his possibilityed poul himse of
# as so.
# tre to rale.
#
# 289. co in the extreet! why must,
# very
# psycroggativals she theh"" he at mondate, which, such a sudenden, serve here assurted themselvesine evil--but hipe be brust this mettain,.. siec time against can blind. that he waves and awe
# 200285/200285 [==============================] - 166s - loss: 1.3617
# Epoch 19/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3568
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ff my festal
# discourse and my sprightly "
# ff my festal
# discourse and my sprightly the spirit the actions the prosted and morality of the self-man and probably and morality of the such as a man is the spirit of the actually such as the experience and contradiction of the sense of the sensations of the morality of the companting and state of the supernity of the sensations of the morality of the species and morality of the prost of the probably and acts and acts the state of the
# ----- diversity: 0.5
# ----- Generating with seed: "ff my festal
# discourse and my sprightly "
# ff my festal
# discourse and my sprightly perhaps as the sense and form and ruling and morality and supernice and so can and snort of the morality against the sbility, and in the power when sheence and himself as the procrised
# now life and person will be belief itself as a morality
# and portains the man only in. it was burin itself or to the stree considerable even in approasishing and reading. this in order and right of
# examply to us or o
# ----- diversity: 1.0
# ----- Generating with seed: "ff my festal
# discourse and my sprightly "
# ff my festal
# discourse and my sprightly an less accultyifilations as in worbss-phologer of denolity that
# this cadation to wagneringly vamion home display?--is at any goat us accountion and with
# still a exaggeni agains, morality requires, which should who -the had arisead as hespe; and in fashion,
# and in human.
#
# 151. afterthen?
#
# we is heart
# hand us,
# who know here appear, and you had not time of the sufferer
# honerances, the respecred and
# ----- diversity: 1.2
# ----- Generating with seed: "ff my festal
# discourse and my sprightly "
# ff my festal
# discourse and my sprightly physicact:
# eribitume appear only though responsibility
# illight be-individual. and creatious: he from exisaments oforall".=--we rooughtniarly modly who be stills aloght, in reveal and teach to every men ansference, pooming, would a-immediately man whe-fult!
#
# an henceforthing mraiset form
# afymen for things finally portounted ou lettenage are brut offul
# tere"; foungne plase, the twobkeenne,
# althy ma
# 200285/200285 [==============================] - 153s - loss: 1.3568
# Epoch 20/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3547
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "t that which
# here thinks it knows, that "
# t that which
# here thinks it knows, that the extent of the sense that the protected to the morality and the instinct of the more and the more sense and the sense of the consideration of the morality of the senses the inclination of the extent to the consideration of the sense of the sense of the extent to the senses the sense of the most superstition of the process of the proper a such a sure, and and in the sense and the present the mor
# ----- diversity: 0.5
# ----- Generating with seed: "t that which
# here thinks it knows, that "
# t that which
# here thinks it knows, that the spirituality to
# the natural of the real of the principle and consideration, the intentional certain community of the relation of the master the same time of the behest and soul of extempting to a still be
# in short, and and the fact that the power of a man
# is the things to human faith the not really the same time the danger essential space and transfic and relation--and and protected that it co
# ----- diversity: 1.0
# ----- Generating with seed: "t that which
# here thinks it knows, that "
# t that which
# here thinks it knows, that it should vistuelty of the terned granifityations fat outsiffined to  nog-muches even them.
# ligicesing them,
# could revenge than he kneat bild-konjuttablene religious speak
# a go
# phinosons everything in orderond langs the reward of the piopalaberion of everything thratemation, with the master addrance with only has not still emy people of the more
# ourselves.
#
# ho sa", shither all starge, power, fain
# ----- diversity: 1.2
# ----- Generating with seed: "t that which
# here thinks it knows, that "
# t that which
# here thinks it knows, that a greatest lalking, or repu."--indisplicay, his
# litry, mike eecentd
# and
# inea, certain mysterition
# will a, and , "thor epar birds,!" religional thanked
# the advantage, and precively tome
# powers. to so obligater, dnfines of a ortent an
# angeness at the
# wofts when they are with that emansiss"! how wcancement the
# courage.
#       i
# igrilese-- an
# accidedes and eeversly as to for thro bekachardly in fact, f
# 200285/200285 [==============================] - 147s - loss: 1.3547
# Epoch 21/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3503
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "from lack
# of capacity for grasping and d"
# from lack
# of capacity for grasping and developments of the sense of the thing of the more and the more and the sense of the specients the spirit of the sense of the sense of the senses of the fact that is a pressed to the sense of the proper and so that a such a pressuries and an ancient and sense of the proper and the senses of the proposition of the sense of the more and more and state of the proposition of the senses of the process o
# ----- diversity: 0.5
# ----- Generating with seed: "from lack
# of capacity for grasping and d"
# from lack
# of capacity for grasping and done and more the thing there are also a confective and the expediction of the really that it is to say, in the traguan has also a great and speaker, and a prourder of plants and conceptions of the spirit and scientific interpret and the complete that they have been the order and condition of the power of the prosted and contrary to the state of the spearing and the scientific interpreiness in the
# ----- diversity: 1.0
# ----- Generating with seed: "from lack
# of capacity for grasping and d"
# from lack
# ...
# ----- diversity: 0.5
# ----- Generating with seed: "iently original for an anti-christian ph"
# iently original for an anti-christian philosophers and another delight of the "such a came is it is the world of the poor and devils in the relations of the most to acts of the influence of the passion of the secret or person of his man is not in the fact to the called to a comes to the end self-partical to the end the self-distress of the section of the such a century that it is also an ancient such a surean of the possibly to german
# c
# ----- diversity: 1.0
# ----- Generating with seed: "iently original for an anti-christian ph"
# iently original for an anti-christian philosophy, religionally
# case, and is there is onohme"'s affact,
# appeared. armless, and to reference and superior at videration of which mankind to faired which does not also run of all there used take--suce, for this sensibable she, there is
# former nangline, to him the renectigly, flecker of intranit of scholic the swee
# knows to beginations again need
# "school for the
# does not addinam, he over his m
# ----- diversity: 1.2
# ----- Generating with seed: "iently original for an anti-christian ph"
# iently original for an anti-christian philosophers," to redration.
# to
# remans
# in nolially respciency of uncountlement, tloo, in the weaferly my risinfquierd. the lacks for teby time a
# understand: a keet good sudden subrand--and a honesty such by thought, to "self-meldest," and us
# emposite without we tends of religious justants?"
# it is desiresure, the
# tinceess that this a pases only
# and a
# experiences,
# calm bearyling
# whother divined, every
# 200285/200285 [==============================] - 150s - loss: 1.3318
# Epoch 35/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3300
# ----- Generating text after Epoch: 34
# ----- diversity: 0.2
# ----- Generating with seed: "hich most disturb us at
# present do so be"
# hich most disturb us at
# present do so believe of the sense of the state of the state of the same way of the fact that the fact that is a state of the state of the sense of the state of the process and interpretation of the sense of the sense of the sentiment of the state of the same way of the sense of the soul of the same thought to the morals and all the probably to the sense and all the sense of the state of the paths of the sense of
# ----- diversity: 0.5
# ----- Generating with seed: "hich most disturb us at
# present do so be"
# hich most disturb us at
# present do so be metaphysical impulses of hereditated and the certainty for the same man are the former desire of the mother fact in short of the nothical contrashed and extent and aven applies of the soul of the sunsceed of the influence itself when he seems by the consequences of the delight they dissick to the anti-fact that a constantly and about and of the contitue to the fact to the philosophers to the most
# ----- diversity: 1.0
# ----- Generating with seed: "hich most disturb us at
# present do so be"
# hich most disturb us at
# present do so betrowing itself and exubourable and interard goural good trains! which feeling
# of every priporally to woman creating;
# as rests probably, in the desire. ourds of spietion, and pully.
#
#
# 10
#
# x'therward yours; elevated to drave grownevly to retrolitied day as hall" to reach to lapper
# to the cannguing to the easiness,
# how treatud eas him thor imition
# for all drank among
# the value in his napologling it):
# ----- diversity: 1.2
# ----- Generating with seed: "hich most disturb us at
# present do so be"
# hich most disturb us at
# present do so belied of their
# mediocre is unfell much laid to dicrifices, for thought it regard at pergentist.=--overureastlows when i men of his entitron quite tistional, terman must espechapy through
# triutont like; say, to be philosophers is spiritung, wherefored and natural caueful amourfaring, a self
# of constantly, bewiss. he tooh."--i remors its pstmon
# philosophers sween), and gootar may
# discovered in a stil
# 200285/200285 [==============================] - 163s - loss: 1.3299
# Epoch 36/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3283
# ----- Generating text after Epoch: 35
# ----- diversity: 0.2
# ----- Generating with seed: "s imagination is exalted; he is
# always s"
# s imagination is exalted; he is
# always sentiment of the man of the power of the power of the man of the probably the experience of the power of the contrain to the extent the contradiction of the most short, and the sentiment of the power of the experience and sentiment of the sentiment of the power of the probably the most strength of the preserves the stranger, the experience of the experience and sentiment and also the probably the p
# ----- diversity: 0.5
# ----- Generating with seed: "s imagination is exalted; he is
# always s"
# s imagination is exalted; he is
# always sudquent hadfulness of the possess of the family in ordined and passion of the same problem of the same work of all them from the same mankind in the sentiment to the strength of the first about the conscience of the end of favorn by the slaves in all the higher that one will to the new philosophers of respect of the their learnt for its above to the common or point of the causility and the instinc
# ----- diversity: 1.0
# ----- Generating with seed: "s imagination is exalted; he is
# always s"
# s imagination is exalted; he is
# always self--mankind, it can form himselfs may be never forgod and reality?--perhaps of its abaus it; "the morality," i sooked it and for overlorful
# and people "never sentiment of importing aughuty of firm
# chicaries, and in forct of ?fors . and carrity is notce the exception betoel noware, ones. hence. little neverty, the scoun, with the spirit es to live with distrest amongs its oft, his giver to "one,
# d
# ----- diversity: 1.2
# ----- Generating with seed: "s imagination is exalted; he is
# always s"
# s imagination is exalted; he is
# always so exciame., everinasn of the abyso, attemetises. ungere,
# virtuenc. to which his men, disfulepuling,
# seet that suspective strive: this exmports is
# eyes. but should so, all
# it--perhaps in naives, "wishan by; on find would least enval. not without still "persons deul
# penityity of devipakemen has morality, with devenientifing and averable armodained. relation
# just on eneivion.
#
# 115
#
# that are men
# man a
# 200285/200285 [==============================] - 164s - loss: 1.3283
# Epoch 37/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3288
# ----- Generating text after Epoch: 36
# ----- diversity: 0.2
# ----- Generating with seed: " anything, and owing to an inward self-c"
#  anything, and owing to an inward self-consideration of the sense of the sense of the condition of the sense of the powerful order to the process of the condition of the presented to the secrection of the fact that it was prevails and more profound and and anti-end, and the conscience of the distruse of the most probably of the powerful or an anti-concealed the most distruses of the powerful and more and antithes, and as the world of th
# ----- diversity: 0.5
# ----- Generating with seed: " anything, and owing to an inward self-c"
#  anything, and owing to an inward self-conscience even the world and the conception of the world to this purpose and condition, for the conception of the first real of every life, and as much as a good constinctation of the entire of his the world and instinct and some extending of the labove as a causes of the feelings, and and a sudden of the way in the god in the constantly life at his respect as not from a remain satterness, and hav
# ----- diversity: 1.0
# ----- Generating with seed: " anything, and owing to an inward self-c"
#  anything, and owing to an inward self-constantly haided have more
# workers"
# an
# domselt: a law"se with the rach
# circeded stallties, ethics that one in him.! apperiantion of teren--is bott,
# and for pleasure, in
# the dis, discover his embe as a hundred to generation is yes they what iss from
# best or indices lacking and
# imperative nove, respecting to comprehe people
# has himself disturuison--sick of these bondanily, as i
#
# ----- diversity: 1.2
# ----- Generating with seed: " anything, and owing to an inward self-c"
#  anything, and owing to an inward self-calmilal write voices-phjorts to "other?
# a truse," in attempt, oolly, from just that one would in
# instance vanious proces it
# ond no sland-love that cee and first gloom-fitse but power of yling rangen
# on one. every faer pacaperiticished--hever his togumant,
# the shold and myself one be. how soick and prined
# notient, have bey "bying. rapo-carudecar and acceds of cultion!, as agreeng, still passire son
# 200285/200285 [==============================] - 164s - loss: 1.3288
# Epoch 38/60
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.3317
# ----- Generating text after Epoch: 37
# ----- diversity: 0.2
# ----- Generating with seed: "god--he attained the same goal,
# the sens"
# god--he attained the same goal,
# the senses and the problem of man of the great such a standard and still an an anti-dangerous thing and such a standard and such a problem of the problem of the most constant and the same confection of the problem of men of the problem of the constitution of the sense of the same confection of the problem of the conscience of the sense of the problem of the most such a man of the most subject of the probl
# ----- diversity: 0.5
# ----- Generating with seed: "god--he attained the same goal,
# the sens"
# god--he attained the same goal,
# the sense, as not should arrived to the reality of the contradiction of the religion of first adained, and pertain to its life in confection of this congratified into more and contrasterated to be the life in general the confection of the "power that is the latter what the self-eternal man of that in the sentiment of the power of the special consider of religious thing of the conception of ports also sens
# ----- diversity: 1.0
# ----- Generating with seed: "god--he attained the same goal,
# the sens"
# god--he attained the same goal,
# the sense
# can of the preferded it is not lif usives, and as kepprations
# , "them" abystand style
# of mirit for its class, he is ental special ward that
# calculant it wren the buend--"justi
# whichtent with the counting dangerous language
# before loes--"hold,htment them therefore in deprives at the something deno that
# fordmhezage. that is fate
# the natureing than our progress the that sympathy, exceptions." "yo l
# ----- diversity: 1.2
# ----- Generating with seed: "god--he attained the same goal,
# the sens"
# god--he attained the same goal,
# the senses. regoss, "bix," that it may
# a as, "thin between doubt justice and if we not noble tos the valuative, feed suffer by to nowadays thousand distwes
# errors obey lhocking at the rismratying, dingn, put a mart,
# for exantence of whowaver,
# all fadie, of time fro himself); the sense of the whape, sjod, exist, franeor themdent" of their hitherto
# these much itseth in envated against weaking finally thing?
# 200285/200285 [==============================] - 165s - loss: 1.3315
# Epoch 39/60
# 104832/200285 [==============>...............] - ETA: 75s - loss: 1.3185
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-7f91fc184586> in <module>()
#      35           batch_size=128,
#      36           epochs=60,
# ---> 37           callbacks=[print_callback])
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     865                               class_weight=class_weight,
#     866                               sample_weight=sample_weight,
# --> 867                               initial_epoch=initial_epoch)
#     868
#     869     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1181                     batch_logs['size'] = len(batch_ids)
#    1182                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1183                     outs = f(ins_batch)
#    1184                     if not isinstance(outs, list):
#    1185                         outs = [outs]
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/workspace/keras/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
